# %%
import numpy as np
# 隐马尔科夫模型参数
states = ['晴天', '雨天']
observations = ['散步', '购物', '清理房间']
start_prob = [0.6, 0.4]
# 状态转移矩阵：A =
# [
#  [0.7, 0.3],  # P(晴天|晴天)=0.7, P(雨天|晴天)=0.3
#  [0.4, 0.6]   # P(晴天|雨天)=0.4, P(雨天|雨天)=0.6
# ]
trans_prob = np.array([
    [0.7, 0.3],
    [0.4, 0.6]
])
# 观测概率矩阵：B =
# [
#  [0.4, 0.4, 0.2],  # P(散步|晴天)=0.4, P(购物|晴天)=0.4, P(清理房间|晴天)=0.2
#  [0.1, 0.3, 0.6]   # P(散步|雨天)=0.1, P(购物|雨天)=0.3, P(清理房间|雨天)=0.6
# ]
emission_prob = np.array([
    [0.4, 0.4, 0.2],
    [0.1, 0.3, 0.6]
])

def viterbi(obs_seq):
    # 将观察序列转换成数字编码，方便计算
    obs_idx = [observations.index(obs) for obs in obs_seq]
    # print("转换序列",obs_idx)
    # 观测序列长度
    T = len(obs_idx)
    # 初始状态矩阵长度
    N = trans_prob.shape[0]
    # 归一化
    log_start_prob = np.log(start_prob)
    log_trans_prob = np.log(trans_prob)
    log_emission_prob = np.log(emission_prob)
    
    V = np.zeros((T, N))
    B = np.zeros((T, N), dtype=np.int64)

    # 初始状态
    V[0] = log_start_prob + log_emission_prob[:, obs_idx[0]]

    for t in range(1, T):
        for j in range(N):
            prob = V[t - 1] + log_trans_prob[:, j]
            # 获取概览最大的
            max_idx = np.argmax(prob)
            # 记录当前路径的概率
            V[t, j] = prob[max_idx] + log_emission_prob[j, obs_idx[t]]
            # 记录路径
            B[t, j] = max_idx
            print(V)

    # 获取最大概率当作路径
    path = [np.argmax(V[-1])]
    for t in range(T - 2, -1, -1):
        path.append(B[t + 1, path[-1]])
    print(path)
    # 将数字编码转换成状态序列
    state_seq = [states[i] for i in path]
    return state_seq
# 观测序列 
obs_seq = ['散步', '散步', '购物', '清理房间']
state_seq = viterbi(obs_seq)
print('观察序列：', obs_seq)
print('最有可能的天气序列：', state_seq)
# Out:
# [[-1.42711636 -3.21887582]
#  [-2.70008203  0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]]
# [[-1.42711636 -3.21887582]
#  [-2.70008203 -4.93367425]
#  [ 0.          0.        ]
#  [ 0.          0.        ]]
# [[-1.42711636 -3.21887582]
#  [-2.70008203 -4.93367425]
#  [-3.97304771  0.        ]
#  [ 0.          0.        ]]
# [[-1.42711636 -3.21887582]
#  [-2.70008203 -4.93367425]
#  [-3.97304771 -5.10802764]
#  [ 0.          0.        ]]
# [[-1.42711636 -3.21887582]
#  [-2.70008203 -4.93367425]
#  [-3.97304771 -5.10802764]
#  [-5.93916056  0.        ]]
# [[-1.42711636 -3.21887582]
#  [-2.70008203 -4.93367425]
#  [-3.97304771 -5.10802764]
#  [-5.93916056 -5.68784614]]
# [1, 0, 0, 0]
# 观察序列： ['散步', '散步', '购物', '清理房间']
# 最有可能的天气序列： ['雨天', '晴天', '晴天', '晴天']

# %%
import xml.etree.ElementTree as ET
import jieba as jb

sentiment_dict = {}
with open('BosonNLP_sentiment_score.txt', 'r', encoding='utf-8') as f:
    for line in f:
        word, score = line.strip().split(" ")
        sentiment_dict[word] = float(score)

tree = ET.parse('ipad评论_情感分析.xml')
root = tree.getroot()
# # 等级词典
level_words = {}
flag = False
level_dict = {'极其|extreme / 最|most': 1, '很|very':0.8,'较|more':0.6,'稍|-ish':0.4,'欠|insufficiently':0.2,'超|over':0.9}
with open('程度级别词语（中文）.txt', 'r', encoding='gbk') as f:
    index = 0
    for line in f:
        line = line.strip()
        if "“" in line:
            line = line.split("\t")
            word = line[0]
            index = eval(line[1])
            leftIndex = word.find("“")
            rightIndex = word.find("”")
            word = word[leftIndex + 1: rightIndex]
            level = level_dict[word]
        elif index > 0:
            index -= 1
            level_words[line] = level
level_words["不"] = -1
# 计算情感值
for review in root:
    text = review.find('sentence').text
    score = 0
    count = 0
    list = jb.cut(text)
    
    for word in list:
        # print(word)
        if word in sentiment_dict:
            value = 1
            if word in level_words.keys():
                value = level_words[word]
            temp =  value * sentiment_dict[word]
            value = 1
            score += temp
            count += 1
    if count != 0:
        score /= count
    print('评论内容：', text)
    print('情感评分：', score)
# Out:
# 评论内容： #iPad3#windows 8  出厂了  但是微软公司 不让零售 额。。。。
# 情感评分： 0.16439247104487692
# 评论内容： #iPad3#神马配置都是渣，求一款平板，可以外接键盘，处理图片日常文件，可以玩主流PC游戏~。
# 情感评分： 0.015928147427286272
# 评论内容： #iPad3#话说，还有2个小时Ipad3就要上市了哦......
# 情感评分： 0.30853511160866426
# 评论内容： #iPad3#the new iPad无可厚非，技术是无价的，国货真不感恭维，像小米m1硬件很犀利，秒杀i9100;而价钱是三星的一半，如果小米卖4000，会有人买吗？
# 情感评分： 0.30002451135701436
# 评论内容： #iPad3#真的会有吗？
# 情感评分： -0.16898763811337503
# 评论内容： #ipad3#今天会随IPAD3一起发布IOS的系统更新吗？
# 情感评分： 0.3295539469962643
# 评论内容： #iPad3#从发布会邀请函上的图片来看真的有点诡异，是这个人手指太小了吗？
# 情感评分： 0.062046749410333224
# 评论内容： #iPad3#有USB接口和宽带接口吗？
# 情感评分： 0.21349390948827265
# 评论内容： #iPad3#很好很贵很xx，香港人用美元吗？？
# 情感评分： 0.10810675526193997
# 评论内容： #iPad3#iPad2与iPad3价格有区别吗？
# 情感评分： 0.3343584682060909
# 评论内容： #ipad3#苹果宣布3月7日发布iPad3苹果公司正式向媒体发布邀请函，将于太平洋时间3月7日上午10点在旧金山芳草地艺术中心（Yerba Buena Center for the Arts）召开下一代iPad的新闻发布会。[
# 情感评分： 0.7466413909475879
# 评论内容： 新一代iPad一定会在诸多方面有所升级，哪一个特性会触碰到你的小神经呢？
# 情感评分： -0.026159645007266683
# 评论内容： 中美物流涨价源于苹果大批#iPad3#秘送至美国http://url.cn/028Xn6  上周有报道称苹果已经开始从中国将iPad 3运送到美国。
# 情感评分： 0.7626514148764871
# 评论内容： #ipad3#苹果将于北京时间3月8日凌晨2:00召开发布会，推出新一代iPad
# 情感评分： 0.8437213020605843
# 评论内容： #iPad3#为什么不支持国产?
# 情感评分： 0.561484443862
# 评论内容： #iPad3#我除了满意屏幕以外，其他都表示很无语，有很大的意思去买吗？
# 情感评分： 0.010237332312044961
# 评论内容： #iPad3#1和2都没用过，管它出什么3。
# 情感评分： 0.20897670803708335
# 评论内容： #iPad3#上市了吗我们这面怎么还没看见啊
# 情感评分： 0.05286113556832307
# 评论内容： #iPad3#苹果说，用户从即日起可以预定新款iPad，有关产品将于3月16日开始率先在美国、澳大利亚、加拿大、法国、中国香港和新加坡等10多个国家和地区率先上市。
# 情感评分： 0.9236151940445826
# 评论内容： #ipad3#IPAD3s要出了吗？
# 情感评分： 0.3389412177771667
# 评论内容： 深圳海关部门：偷带#ipad3#入境属违法行为。
# 情感评分： 0.46885309557407
# 评论内容： #ipad3#会在任务栏上面增加一些手势吗？
# 情感评分： 0.02797612345180004
# 评论内容： #iPad3#目前人在美国，需要代购的请联系我.
# 情感评分： 0.46210660121016
# 评论内容： #iPad3#与4和4S一样，除了像素和运行速度等提升，其实我看来没多大区别，也许苹果不想再愚弄一次果迷或不愿把IPAD3叫做IPAD2B吧。
# 情感评分： 0.32945582978351207
# 评论内容： #iPad3#时间：北京时间3月8日凌晨2点（当地时间3月7日上午10点） 地点：旧金山芳草地艺术中心  北京时间2月29日凌晨，苹果正式向媒体发送新一代iPad发布会邀请函，只有这样一段话：“我们有一些东西你必须要看一下，摸一下
# 情感评分： 0.43490264366190684
# 评论内容： #iPad3#没了老乔的苹果能走多远呢?
# 情感评分： 0.3521106047380171
# 评论内容： #iPad3#会不会有中文Siri发布呀
# 情感评分： 0.28950443139437776
# 评论内容： #iPad3#在中国，ipad3的价格不会低的，因为中国可能晚上市，急需要的人需要卖高价的从不正常渠道来的货。
# 情感评分： 0.19010305391794244
# 评论内容： #iPad3#什么时候能在中国上市
# 情感评分： 0.35827124004477784
# 评论内容： #iPad3#  IPAD这商标还能用吗？
# 情感评分： 0.0032502607709727197
# 评论内容： #iPad3#新一代iPad将于3月16日在美国、加拿大、英国、法国、德国、瑞士、日本、中国香港、新加坡、澳大利亚等地区首先发售。
# 情感评分： 0.7258295277771727
# 评论内容： #iPad3#这么麻烦的东西怎么还有那么多人在用，又是越狱又是破解。
# 情感评分： -0.311741732890735
# 评论内容： #视频分享#【#iPad3#震撼演示视频曝光！！
# 情感评分： 1.1067464023747713
# 评论内容： #ipad3#看看ipad3怎么样子，不要像ipad2一样
# 情感评分： 0.3081539521860818
# 评论内容： #ipad3#苹果公司正式向媒体发布邀请函，将于太平洋时间3月7日上午10点在旧金山芳草地艺术中心（Yerba Buena Center for the Arts）召开下一代iPad的新闻发布会。[
# 情感评分： 0.8218749274761243
# 评论内容： #iPad3#看来我最后一个肾也保不住了，我又看上它了，怎么办？
# 情感评分： -0.2898422779077345
# 评论内容： #iPad3#为什么你们都这么的迷恋乱苹果？
# 情感评分： -0.071164410088025
# 评论内容： #iPad3# 222都没买，只能用安卓的，出3了……
# 情感评分： -0.00021561568297999342
# 评论内容： #iPad3#我正好想买一个，成都市哪儿有卖的。
# 情感评分： 0.17748718747412137
# 评论内容： #iPad3#嘉宾认为这次ipad为什么没有新名字？
# 情感评分： 0.17125009693690452
# 评论内容： #iPad3#祝愿苹果能出更优秀的产品，以此刺激一下中国睡狮
# 情感评分： 0.9359467137283142
# 评论内容： #iPad3#中国大陆市场的iPad商标权还木夺来呢！！！
# 情感评分： 0.3010212354863417
# 评论内容： #ipad3# 【新一代iPad准备揭晓！
# 情感评分： 1.1885810146434144
# 评论内容： #iPad3#现在越来越喜欢了～～～Ｒｍｂ也才３０００多，比我的垃圾小笔记本还要便宜的多，当初为嘛不想买呢？
# 情感评分： 0.2548824629958679
# 评论内容： 苹果刚刚关闭在线商店，这预示着新品正在上架。
# 情感评分： 0.32842589547267503
# 评论内容： #ipad3#iPad3不知道性能好不好，如果好的话可以考虑买一个，永远怀念乔布斯
# 情感评分： 0.5254910016485649
# 评论内容： #ipad3#强烈建议不要引进中国
# 情感评分： 0.9553824643488001
# 评论内容： #ipad3#不差钱也不买。
# 情感评分： 0.6061751307585401
# 评论内容： #ipad3#是乔布斯早就设计好的产品吧。
# 情感评分： 0.6307015160468668
# 评论内容： #iPad3#怎么一直没有说新ipad的命名啊？
# 情感评分： -0.026465505174749982
# 评论内容： #ipad3#新iPad有2047 x 1536视网膜屏幕！
# 情感评分： 0.5291837080880778
# 评论内容： #iPad3#果发布全新一代iPad 北京时间3月8日凌晨两点，苹果公司在旧金山芳草地艺术中心发布了全新一代的iPad。
# 情感评分： 0.5983197658603463
# 评论内容： #iPad3#会长成虾米样子呢？
# 情感评分： 0.13696609744007499
# 评论内容： 随着新一代#ipad3#的发布，新固件ios5.1也随之提供下载，日语版 Siri 将会是 iOS 5.1 的一部分，真给力，可以与Siri用日语对话了
# 情感评分： 0.4179366366284643
# 评论内容： 果粉们，Apple 已确定於今天早上10点召开#iPad3#全球发布会。
# 情感评分： 0.7785378768242942
# 评论内容： #iPad3#其实美国心机挺大的，这么多中国SB上当了  刚开始出个3GS 等你们得瑟的时候乘机又出个iPhone4 ，当iPhone4俘虏一群青年党时，又立即掀起一股苹果潮 接连推出4GS，而如今ipad3出来了 你认为iPhone5 iPhone5S还有几个月推出呢？
# 情感评分： 0.4088761672181154
# 评论内容： #iPad3#美国大骗子又来咯 等他iPhone5的时候 他出个4S  现在出ipad3 肯定出个2.5哈哈
# 情感评分： 0.40866858317069216
# 评论内容： #iPad3#苹果公司将在北京时间3月8日凌晨2:00，也就是在数小时之的美国旧金山召开产品发布会，预计将宣布推出新一代iPad。
# 情感评分： 0.49725692049598447
# 评论内容： #ipad3#北京时间2月29日消息，据国外媒体报道，苹果公司正式向媒体发布邀请函，将于太平洋时间3月7日上午10点在旧金山芳草地艺术中心（Yerba Buena Center for the Arts）召开下一代iPad的新闻发布会。
# 情感评分： 0.6995581167686745
# 评论内容： #iPad3#4G？
# 情感评分： 0.5022106643458
# 评论内容： 腾讯数码:数码大叔为大家制作的新iPad全方位解析，点击图放大观看。
# 情感评分： 0.8261849575502936
# 评论内容： #iPad3# 【新iPad要点汇总】全新的iPad发布，4大特性：配备Retina显示屏，分辨率是iPad2的四倍；
# 情感评分： 0.7644872502274801
# 评论内容： 抢先看：苹果#iPad3#发布会场地外景】苹果下一代iPad发布会现场，加州旧金山芳草地艺术中心开始布置外景，会场外墙上已经出现我们再熟悉不过的苹果Logo！
# 情感评分： 0.9238761249179137
# 评论内容： #90ITer# #ipad3#苹果新一代IPAD产品出炉了~发布会结束了几个小时，视频的中文字幕就出来了。。。
# 情感评分： 0.6004476956348417
# 评论内容： #iPad3#我很想知道，深陷官司中的Ipad怎么命名呢？
# 情感评分： -0.08511981666912943
# 评论内容： #iPad3#没有中国﹑苹果能有现在。
# 情感评分： 0.44585739163247
# 评论内容： #iPad3#对于列陈出新的苹果ipad，iphone，除了能说明发达科技进万家，更多形成人们追逐的玩物，促成攀比。
# 情感评分： 0.6188653221853629
# 评论内容： /抓狂#ipad3#万恶的IPAD3啊，为什么SIRI不能有中文的，4G中国多久才能有，那极限般的无线下载速度啊
# 情感评分： -0.22384241463276086
# 评论内容： #iPad3#没有了Jobs，苹果的创新就仅限与此了吗？
# 情感评分： 0.4646978800332666
# 评论内容： #iPad3#中关村在线消息：2012苹果iPad新品发布会已经结束，蒂姆库克仿佛在调全球媒体的胃口，在介绍iPad新品时没有公布其正式名称。
# 情感评分： 0.732712847520303
# 评论内容： #iPad3#苹果产品是知识的结晶，靠的是科技和创新，请一些想要不劳而获的仕途打消对人家贪婪的妄想，大家看的是品质不是一个名字，即使人家换个陌生的名字，不出声人们也会去买。
# 情感评分： 0.2713381808402675
# 评论内容： #iPad3#我是近期不会购买的.因为我转投安卓了
# 情感评分： 0.3571740974591908
# 评论内容： #ipad3#这是苹果公司衰落的开始！
# 情感评分： 0.4115006025266572
# 评论内容： #iPad3#10年底买了ipad1，觉得真是好用，每天的使用时间超过了10小时；
# 情感评分： 0.11369416597940951
# 评论内容： #iPad3#我是纯血统的 果粉，支持IPAD 3的 到来， 支持后乔布斯盛世...
# 情感评分： 0.746867041646155
# 评论内容： #iPad3#感觉乔布斯似乎带走了苹果所有的想像与创意。
# 情感评分： 0.6845081752420284
# 评论内容： #iPad3#前几年ipad1刚出来的时候感到非常新奇，赶快买了一台，上手以后感觉操控性能各方面都还不错，只是有些性能不是很全，没多久ipad2出来了，有了照相的功能，可以做视频了赶快去买了一台，回来一试很遗憾拍摄的照片清晰度还没手机好。
# 情感评分： 0.3439929539839968
# 评论内容： #iPad3# 不是太贵吧。
# 情感评分： 0.23488453917545002
# 评论内容： #iPad3#应该不会有太大惊喜，更期待Apple TV或者iTV神马的~
# 情感评分： 0.6969431577095069
# 评论内容： #ipad3#...
# 情感评分： 0.9241138504385
# 评论内容： #ipad3#好想拥有一部，只是现在的IPAD2怎么办？
# 情感评分： 0.146400713609
# 评论内容： #ipad3#对于ipad3，并没有像iphone4那样带来的惊讶之感，更多的只是“哦，这样啊！
# 情感评分： 0.378409036067826
# 评论内容： #iPad3#果断不期待 又该搞出来个iPad2S..iPad2B怎么样/呲牙
# 情感评分： -0.08627659512669232
# 评论内容： 美国当地时间3月7日上午11点（北京时间3月8日凌晨2点）在美国旧金山的芳草地艺术中心新品举办2012年首场新品发布会。
# 情感评分： 0.8062433864741562
# 评论内容： #ipad3#苹果公司的东西都是忽悠人的，榨干中国农民工的血汗得来的所谓高端产品。
# 情感评分： 0.1605048597052762
# 评论内容： #ipad3#显示效果处理性能强大，看来驾驭1080P高码率视频已经手拿把攥了  现在话题又扯回到A5X处理器上，仍然是双核…
# 情感评分： 0.30579206546575327
# 评论内容： #iPad3#老乔不在了，苹果有点落寞啊
# 情感评分： 0.1289960753998454
# 评论内容： 苹果“新一代”iPad 3，于北京时间今日凌晨两点，苹果公司在旧金山芳草地艺术中心发布了其第三代平板电脑产品，不过让人有一点失望，不是叫易记的IPAD 3，而改成了The new iPad，变的不三不四了．#ipad3#
# 情感评分： 0.32763289012691704
# 评论内容： #iPad3#终审结果出来了吗?
# 情感评分： 0.09834177193933334
# 评论内容： #ipad3#屏幕的升级是亮点，缺失800万像素的摄像头算个遗憾吧。
# 情感评分： 0.14682535159995883
# 评论内容： #iPad3#   这代的 ipad 突破性很大啊 又是一部 要大卖的产品.4大特性：配备Retina显示屏，分辨率是iPad2的四倍；
# 情感评分： 0.28922757293499235
# 评论内容： #ipad3#今天我去了手机电脑城，看到iPad3界面挺大，比笔记本电脑轻薄多了，使用起来清晰舒服。
# 情感评分： 0.3098846659866056
# 评论内容： #iPad3#siri什么时候才能支持中文
# 情感评分： 0.39496685666335557
# 评论内容： #iPad3#不要去跟风了，实在意义不大，为了娱乐，可以考虑别的平板。
# 情感评分： 0.2298319731498
# 评论内容： #iPad3#出就出呗，不怎么期待。
# 情感评分： 0.3975277139808
# 评论内容： #ipad3#我个人觉得没有乔布斯的新产品发布会就是没有那么创新，有些软件我觉得太过于啰嗦了吧。
# 情感评分： 0.32603860174943344
# 评论内容： #ipad3#新的iPad拥有Siri，支持4G LTE！
# 情感评分： 1.0704658454882583
# 评论内容： #ipad3# 被大家寄予厚望的ipad3终于发布了，看了半天，感觉只有一个，乔布斯走远了，苹果也走远了。
# 情感评分： 0.21393995911874247
# 评论内容： #iPad3#这那是神马ipad3啊;在发布会上写的都是The New Ipad.干脆就叫它ipad2Bs吧;更新的4G网络国内根本用不了;玩毛线...
# 情感评分： 0.08780903090561701
# 评论内容： #iPad3#不如预期的nb，不过是改进了摄像头，改进了电池，改进了触控，还从3G变成了4G，我不用摄像头拍照，电池够用，只用wifi，而且喜欢轻便，so还是ipad2比较适合我。
# 情感评分： 0.2561364151339341

# %%
import pandas as pd
from sklearn.metrics import r2_score

sms_df = pd.read_csv('../smsspamcollection/SMSSpamCollection', delimiter='\t', 
                     header=None, names=['class', 'text'])
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# 预处理数据
sms_df['text'] = sms_df['text'].apply(lambda x: x.lower().split())
vectorizer = CountVectorizer()
# 使用scikit-learn库提供的CountVectorizer类将单词列表转换为词频矩阵。
X = vectorizer.fit_transform(sms_df['text'].apply(lambda x: ' '.join(x)))
# 区分垃圾邮件与正常邮件
y = sms_df['class'].apply(lambda x: 1 if x == 'spam' else 0)
# print(X)
# 划分为训练集和测试集 

from sklearn.naive_bayes import MultinomialNB
def result(X_train,y_train,X_test,y_test):
# 训练朴素贝叶斯分类器
    clf = MultinomialNB()
    clf.fit(X_train, y_train)

    # 在测试集上评估分类器
    accuracy = clf.score(X_test, y_test)
    y_pre=clf.predict(X_test)
    r2 = r2_score(y_pre, y_test)
    print('Accuracy:', accuracy)
    print("r_score",r2)
print("----------------使用5000+574-----------------")
X_train, X_test, y_train, y_test = X[:5000], X[5000:], y[:5000], y[5000:]
result(X_train,y_train,X_test,y_test)
print("----------------使用随机划分(8:2)-----------------")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
result(X_train,y_train,X_test,y_test)
print("---------------使用3000+2574----------------")
X_train, X_test, y_train, y_test = X[:3000], X[3000:], y[:3000], y[3000:]
result(X_train,y_train,X_test,y_test)
# Out:
# ----------------使用5000+574-----------------
# Accuracy: 0.993006993006993
# r_score 0.9393039049235993
# ----------------使用随机划分(8:2)-----------------
# Accuracy: 0.9781048097631012
# r_score 0.8103207156529553
# ---------------使用3000+2574----------------
# Accuracy: 0.9797822706065319
# r_score 0.8246348307240448
